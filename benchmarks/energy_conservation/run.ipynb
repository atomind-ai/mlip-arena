# %%
from ase.io import read

structures = read("../mptrj_eq_test.extxyz", index=":")

# %%
import random
import os
from ase.io import read
from tqdm.auto import tqdm

# get a subset of mptrj
random.seed(88)


def random_sample_from_directory(directory, sample_size):
    files = sorted(os.listdir(directory))  # Get all files
    files = [f for f in files if os.path.isfile(os.path.join(directory, f))]  # Filter only files
    sample = random.sample(files, min(sample_size, len(files)))  # Pick random sample
    return sample


data_dir = "./christine/mlip-arena/mptrj"
sample_size = 5000

random_files = random_sample_from_directory(data_dir, sample_size)

# num_structures_per_file = []
reference_structures = []
for file in tqdm(random_files):
    traj = read(os.path.join(data_dir, file), index=":")
    reference_structures.append(traj[len(traj) // 2])
    # num_structures_per_file.append(len(traj))

# sum(num_structures_per_file)

# %%
import numpy as np

subset_indices = np.load("./christine/mlip-arena/mptrj_subset_descriptor_indices.npy")

# %%
subset_indices
# Out:
# array([   0,    0,    0, ..., 5317, 5317, 5317], shape=(161035,))

# %%
from mlip_arena.models import MLIPEnum
from mlip_arena.flows.conservation import differential_entropy_along_nve_trajectory

MLIPEnum.__members__

# %%
import torch
from mlip_arena.models import MLIPEnum
from pathlib import Path
from prefect.task_runners import ThreadPoolTaskRunner

differential_entropy_along_nve_trajectory.with_options(
    task_runner=ThreadPoolTaskRunner(max_workers=torch.cuda.device_count()), persist_result=False
)(
    model="MACE-MPA",
    structures=traj,
    reference_path=Path("../mptrj_eq_test.extxyz"),
    start_idx=0,
    end_idx=-1,
    step=100,
)
# Out:
# 2026-03-26 23:10:14.079 | INFO     | mlip_arena.models:_make_mlip_enum:69 - Skipping deprecated models: ['eqV2(OMat)', 'eSEN', 'EquiformerV2(OC22)', 'EquiformerV2(OC20)', 'eSCN(OC20)', 'ORB']
# 2026-03-26 23:10:14.082 | INFO     | mlip_arena.models:_make_mlip_enum:71 - Registered models: ['MACE-MP(M)', 'CHGNet', 'M3GNet', 'MatterSim', 'ORBv2', 'SevenNet', 'MACE-MPA', 'MACE-OFF(M)', 'ANI2x', 'ALIGNN', 'DeepMD', 'NequIP-OAM-L', 'UMA-S-1P1']
# ...

# %%
import e3nn

e3nn.__version__
# Out:
# '0.4.4'

# %%
MLIPEnum["UMA-S-1P1"]()
# Out:
# Warp CUDA error 2: out of memory (in function get_context_info, /builds/omniverse/warp/warp/native/warp.cu:388)
# Warp CUDA error 2: out of memory (in function get_context_info, /builds/omniverse/warp/warp/native/warp.cu:389)
# Warp CUDA error 2: out of memory (in function wp_cuda_context_is_primary, /builds/omniverse/warp/warp/native/warp.cu:2268)
# Warp CUDA error 2: out of memory (in function wp_cuda_context_is_primary, /builds/omniverse/warp/warp/native/warp.cu:2268)
# Warp CUDA error 709: context is destroyed (in function wp_cuda_stream_create, /builds/omniverse/warp/warp/native/warp.cu:2554)
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /pscratch/sd/c/cyrusyc/.conda/mlip-arena/lib/python3.12/site-packages/nvalchemiops/__init__.py in ?()
#      22     wp.init()
#      23 except RuntimeError as e:
# ---> 24     raise RuntimeError(
# ...

# %%
import torch
from mlip_arena.flows.conservation import differential_entropy_along_nve_trajectory
from mlip_arena.models import MLIPEnum
from pathlib import Path
from prefect.task_runners import ThreadPoolTaskRunner

differential_entropy_along_nve_trajectory.with_options(
    task_runner=ThreadPoolTaskRunner(max_workers=torch.cuda.device_count()), persist_result=False
)(
    model="MACE-MPA",
    structures=traj[:5],
    reference_path=Path("../mptrj_eq_test.extxyz"),
    start_idx=0,
    end_idx=-1,
    step=100,
)
# Out:
# /pscratch/sd/c/cyrusyc/.conda/mlip-arena/lib/python3.12/site-packages/e3nn/o3/_wigner.py:10: UserWarning: Environment variable TORCH_FORCE_NO_WEIGHTS_ONLY_LOAD detected, since the`weights_only` argument was not explicitly passed to `torch.load`, forcing weights_only=False.
#   _Jd, _W3j_flat, _W3j_indices = torch.load(os.path.join(os.path.dirname(__file__), 'constants.pt'))
# cuequivariance or cuequivariance_torch is not available. Cuequivariance acceleration will be disabled.
# 2026-03-20 00:07:25.972 | WARNING  | mlip_arena.models:<module>:54 - Failed to load model MatterSim due to ImportError. Skipping.
# 2026-03-20 00:07:25.973 | DEBUG    | mlip_arena.models:<module>:55 - Error details: cannot import name 'full_3x3_to_voigt_6_stress' from 'ase.constraints' (/pscratch/sd/c/cyrusyc/.conda/mlip-arena/lib/python3.12/site-packages/ase/constraints/__init__.py)
# ...
